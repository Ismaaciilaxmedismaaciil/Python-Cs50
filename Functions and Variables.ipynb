# %% [markdown]
# ## Functions and Variables

# %%
print('Hello, world')
# Out:
# Hello, world

# %%
name = input("What's your name? ")


# Removing Defualt whitespace seperater and new line
print('Hello',name, sep='**', end=' ')
print(name)
# Out:
# Hello**Ismailk Ismailk

# %%
# Escaping

# Example
print('My name\'s Ismial Ahmed Ismail')

# Another Example
print("Hello \"Ismail\"")
# Out:
# My name's Ismial Ahmed Ismail
# Hello "Ismail"
